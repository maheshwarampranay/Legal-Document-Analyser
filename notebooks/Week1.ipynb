# %% [markdown]
# ### The virtual env setup and installation of all modules is done. Please refer to the requirements.txt for the list of required modules

# %% [markdown]
# ## Imports

# %%
#importing the packages
import langchain
import langgraph
import pinecone
import pypdf
import tiktoken

# %%
#loading the .env file
from dotenv import load_dotenv
import os
env_path = os.path.abspath(os.path.join(os.getcwd(), "..", ".env"))
load_dotenv(env_path)
# Out:
# True

# %%
from langchain_community.document_loaders import PyPDFLoader
import re

# %%
from ipywidgets import FileUpload
uploader = FileUpload(accept=".pdf", multiple=False)
uploader
# Out:
# FileUpload(value=(), accept='.pdf', description='Upload')

# %%
uploader.value
# Out:
# ({'name': 'sample-doc.pdf',
#   'type': 'application/pdf',
#   'size': 461010,
#   'content': <memory at 0x000002546CF6A380>,
#   'last_modified': datetime.datetime(2025, 12, 5, 13, 27, 46, 557000, tzinfo=datetime.timezone.utc)},)

# %%
if uploader.value:
    uploaded_file = uploader.value[0]  # tuple → first element

    file_name = uploaded_file['name']
    content = uploaded_file['content']  # memoryview object

    # Convert memoryview → bytes
    content_bytes = bytes(content)

    # Save file locally
    save_path = f"sampledocs/{file_name}"  # or "uploaded_contract.pdf"
    with open(save_path, "wb") as f:
        f.write(content_bytes)

    print("Saved file as:", save_path)
else:
    print("No file uploaded yet!")
# Out:
# Saved file as: sampledocs/sample-doc.pdf

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(save_path)
pages = loader.load()

print("Pages:", len(pages))
# Out:
# Pages: 66

# %%
print(pages[1].page_content[:500])
# Out:
# 2
#
#
# 1. SALE:
#   The sale deed is the main document by which a seller transfers his right on the property to the
# purchaser, who then acquires absolute ownership of the property. It is also referred to as the
# conveyance deed. On completion of all formalities, a sale deed is prepared. This is the main
# document for transfer of ownership of property. The  deed is executed by all the parties concerned.
# All pages of the deed are to be signed. The deed should be witnessed by at least two witnesse

# %% [markdown]
# ## Content Cleaning

# %%
# Combine all pages into a single raw text
raw_text = "\n".join(page.page_content for page in pages)

print("Raw text preview:\n")
print(raw_text[:500])
print("\n---")
print(f"Total characters: {len(raw_text)}")
# Out:
# Raw text preview:
#
# 1
#
# Introduction:
# Registration refers to the recording of the content s of a document with a Registering
# Officer appointed by the Government. The main purpo se of registration is to ensure information
# about all deals are recorded and maintained apart f rom giving the document its authenticity. It
# gives information to the people regarding legal rig hts and obligations arising or affecting a
# particular property. The registered documents may a fterwards be of legal importance, and also
# aid i
#
# ---
# Total characters: 175181

# %%
import re

def clean_text(text: str) -> str:
    text = text.replace("\x00", "")  # remove null bytes
    text = re.sub(r"\s+", " ", text)  # collapse whitespace
    return text.strip()

cleaned_text = clean_text(raw_text)

print("Preview after cleaning:\n")
print(cleaned_text[:500])
print("\n---")
print("Total words:", len(cleaned_text.split()))
# Out:
# Preview after cleaning:
#
# 1 Introduction: Registration refers to the recording of the content s of a document with a Registering Officer appointed by the Government. The main purpo se of registration is to ensure information about all deals are recorded and maintained apart f rom giving the document its authenticity. It gives information to the people regarding legal rig hts and obligations arising or affecting a particular property. The registered documents may a fterwards be of legal importance, and also aid in prevent
#
# ---
# Total words: 28911

# %%
heading_pattern = r"\b([A-Z][A-Z\s]{3,})\b"

headings = re.findall(heading_pattern, cleaned_text)
unique_headings = list(dict.fromkeys([h.strip() for h in headings]))  # remove duplicates, keep order

unique_headings
# Out:
# ['NOC',
#  'SALE',
#  'GENERAL SALE DEED',
#  'VENDOR',
#  'VENDEE',
#  'NOW THIS DEED OF SALE WITNESSETH AS FOLLOWS',
#  'RLSC',
#  'ALSC',
#  'THE MEASUREMENTS',
#  'IN WITNESS WHEREOF',
#  'SALE DEED',
#  'VENDOR VENDEE WITNESSES',
#  'GIFT',
#  'DEED OF GIFT OF IMMOVABLE PROPERTY THIS DEED OF GIFT',
#  'DONOR',
#  'DONEE',
#  'WHEREAS',
#  'AND WHEREAS',
#  'NOW THIS DEED WITNESSETH',
#  'AND',
#  'DON EE',
#  'AND FURTHER',
#  'SCHEDULE',
#  'MORTGAGE',
#  'SIMPLE MORTGAGE DEED',
#  'MORTGAGOR',
#  'ONE PART',
#  'MORTGAGEE',
#  'OTHER PART',
#  'NOW THIS DEED WITNESSETH THAT',
#  'AND THIS DEED FURTHER WITNESSETH THAT',
#  'AND IT IS HEREBY AGREED AND DECLARED',
#  'AND IT IS FURTHER AGREED AND DECLARED',
#  'AND IT IS FURTHER AGREED',
#  'AND IT IS FURTHER AGREED BY THE MORTGAGOR',
#  'WITNESSES',
#  'DEED OF MORTGAGE BY CONDITIONAL SALE THIS DEED OF',
#  'VEN DOR',
#  'PURCHASER',
#  'TO HOLD',
#  'THE SCHEDULE ABOVE REFERRED TO',
#  'LEASE',
#  'GENERAL LEASE DEED',
#  'LESSOR',
#  'LESSEE',
#  'NOW THIS DEED WITNESSETH AS FOLLOWS',
#  'THE LESSOR HEREBY DEMISES UNTO THE LESSEE ALL THAT',
#  'TOGETHER WITH ALL',
#  'TOGETHER WITH',
#  'IT IS HEREBY EXPRESSLY AGREED BETWEEN THE PARTIES AS FOLLOWS',
#  'COMMERCIAL LEASE DEED',
#  'LANDL ORD',
#  'TENANT',
#  'WHERE IT IS AGREED AND DECLARED AS FOLLOWS',
#  'PREMISES',
#  'WITNESS WHEREOF',
#  'LEASE OF FURNISHED HOUSE FOR RESIDENTIAL PURPOSE THIS LEASE',
#  'LANDLORD',
#  'DEED OF SURRENDER OF LEASE THIS DEED',
#  'BETWEEN',
#  'OT HER PART',
#  'AND THE LESSEE',
#  'LEAVE AND LICENCE',
#  'LEAVE AND LICENCE AGREEMENT THIS AGREEMENT OF LEAVE AND LICENCE',
#  'NOW THIS AGREEMENT TO LEAVE AND LICENCE WITNESSETH AND IT IS HEREBY AGREED BY AND THE PARTIES HERETO',
#  'SIGNED SEALED AND DELIVERED',
#  'PARTNERSHIP DEED',
#  'DEED OF PARTNERSHIP',
#  'AND A',
#  'NOW THIS DEED WINTESSETH AS UNDER',
#  'VAT',
#  'IN WITNESSES WHEREOF',
#  'WITNESSESS',
#  'TRUST DEED',
#  'DEED OF TRUST THIS DEED OF TRUST',
#  'SETTLOR',
#  'OF THE ONE PART AND',
#  'O SHRI',
#  'NOW THIS DEED OF TRUST WITNESSTH AS FOLLOWS',
#  'TRUSTEES',
#  'SETTLOR WITNESS',
#  'TRUSTEE',
#  'BONDS A',
#  'SIMPLE MONEY BOND I',
#  'MONEY BOND WITH SURETY',
#  'DEBTOR',
#  'SURETY',
#  'WHEREAS XY',
#  'NOW BY THIS BOND',
#  'IN WRITTEN',
#  'AB CD INDEMNITY BOND',
#  'NOW THIS DEED OF INDEMNITY WITNESSETH AS UNDER',
#  'INDEMNIFIERS',
#  'PARTNERSHIP AGREEMENTS',
#  'DEED OF DISSOLUTION THIS DEED OF DISSOLUTION',
#  'PARTY OF THE FIRST PART',
#  'CONTINUNING PARTY',
#  'PARTY OF THE FOURTH PART',
#  'RETIRING PARTY',
#  'NOW THEREFORE THIS DISSOLUTION WITNESSED AS UNDER',
#  'THAT',
#  'IN WITNESS',
#  'EXCUTANTS',
#  'OWNERSHIP AGREEMENT THIS AGREEMENT',
#  'BETWEEN MR',
#  'AND MR',
#  'NOW THIS AGREEMENT WITNESSETH',
#  'THE SCHEDULE ABOVE REFERRED',
#  'SIGNEDAND DELIVERED',
#  'SIGNED AND DELIVERED',
#  'DEED OF PARTITION BETWEEN CO',
#  'OWNERS',
#  'DEED OF PARTITION',
#  'RELINQUISHMENT',
#  'RELEASE',
#  'RELINQUISHMENT DEED',
#  'EXECUTANTS',
#  'RELEASORS',
#  'IN FAVOUR OF',
#  'RELEASEE',
#  'NOW THIS DEED WITNESSETH AS UNDER',
#  'RELEASORS WITNESSES',
#  'EXCHANGE',
#  'EXCHANGE DEED',
#  'PARTY OF THE SECOND PART',
#  'TO HAVE AND TO HOLD',
#  'FIRST SCHEDULE',
#  'SECOND SCHEDULE',
#  'FIRST PARTY SECOND PARTY WITNESSES',
#  'THIS DEED OF EXCHANGE',
#  'NOW THEREFORE THIS DEED WITNESSES',
#  'ALL THAT',
#  'CANCELLATION',
#  'CANCELLATION DEED',
#  'BUYER',
#  'SELLER',
#  'NOW THIS CONTRACT WITNESSETH',
#  'SCHEDULE IN WITNESS WHEREOF',
#  'POWER OF ATTORNEY A',
#  'GENERAL POWER OF ATTORNEY',
#  'GENERAL POWER OF ATTORNEY TO ALL TO WHOM THESE PRESENTS SHALL COME',
#  'WHEREAS I',
#  'AND WHEREAS I',
#  'NOW KNOW BY THESE PRESENTS',
#  'AND I',
#  'SPECIAL POWER OF ATTORNEY',
#  'POWER OF ATTORNEY TO EXECUTE SALE DEED BY THIS POWER OF ATTORNEY',
#  'DEED OF REVOCATION OF POWER OF ATTORNEY THIS DEED OF REVOCATION OF POWER OF ATTORNEY',
#  'NOW THIS DEED OF REVOCATION WITNESSETH AS FOLLOWS',
#  'IN WITNESS WHEREOF I',
#  'EXECUTANT',
#  'WILLS',
#  'WILL I',
#  'ADOPTION DEED',
#  'GENERAL ADOPTION DEED THIS DEED',
#  'NOW THIS DEED WITNESSESETH AS FOLLOWS',
#  'THE ADOPTIVE FATHER THE NATURAL FATHER',
#  'WITNESS',
#  'ADOPTION OF AN ORPHAN FROM AN ORPHANAGE THIS DEED',
#  'NOW I',
#  'SETTLEMENT',
#  'FAMILY SETTLEMENT BETWEEN THE HEIRS OF A DECEASED']

# %%
clauses = {}

for i, heading in enumerate(unique_headings):
    start = cleaned_text.find(heading)
    
    if i < len(unique_headings) - 1:
        end = cleaned_text.find(unique_headings[i + 1])
    else:
        end = len(cleaned_text)
    
    clause_text = cleaned_text[start:end].strip()
    clauses[heading] = clause_text

# Show first clause block as sample
first_key = list(clauses.keys())[0]
clauses[first_key][:800]
# Out:
# 'NOC from local authorities if the document for regi stration conveys land converted as house site without the approval layout. (i) Patta transfer application duly filled and signed. Compulsory registrable documents: Sl.No Situation / documents 1. Instruments of gift of immovable property 2. Other non-testamentary instruments which purport or operate to create, declare, assign, limit or extinguish, whether in present or in future, any right, title or interest, whether vested or contingent, of the value of one h undred rupees, and upwards, to or in immovable property 3. Non-testamentary instruments which acknowledge t he receipt or payment of any consideration on account of the creation, declarati on, assignment, limitation or extinction of any such right, title or interest 4. Leases of immo'

# %%
import re

heading_pattern = r"""
(
    ^\d{1,2}\.\s+.*?$       # e.g., 1. Payment Terms
  | ^\d{1,2}\.\d{1,2}\s+.*?$  # e.g., 1.1 Sub clause
  | ^[A-Z][A-Z\s]{3,}$      # ALL CAPS headings
)
"""

matches = re.findall(heading_pattern, raw_text, re.MULTILINE | re.VERBOSE)
matches
# Out:
# ['1. Instruments of gift of immovable property ',
#  '2. Other non-testamentary instruments which purport  or operate to create, declare, ',
#  '3. Non-testamentary instruments which acknowledge t he receipt or payment of any ',
#  '4. Leases of immovable property from year to year, or for any term exceeding one ',
#  '5. Non-testamentary instruments transferring or ass igning any decree or order of a ',
#  '6. Authority to adopt a son and not conferred by a Will.',
#  '1. SALE: ',
#  'GENERAL SALE DEED \n ',
#  '1.  That in consideration of payment of Rs…………………(Rupee s……………………….) only ',
#  '2. \n That the Vendor hereby assures the Vendee that the said property is free from all kinds of ',
#  '3.  That the Vendor further covenants with the Vendee t hat knowingly or otherwise he has not ',
#  '4.  That the Vendor further assures the Vendee that he has got a clear, effectual, subsisting ',
#  '5.  That the Vendor further covenants with the Vendee t hat if there remains any undisclosed ',
#  '6.  That the Vendor further agrees to indemnify the Ven dee and keep him free from disputes if ',
#  '7.  That the Vendor also assures the Vendee that if the re remains any liability of taxes or rates ',
#  '8.  The Vendor further assures and covenants with the V endee that the Vendee and his heirs ',
#  '9.  That the Vendor does hereby put the purchaser in ac tual physical possession of the ',
#  '10.  That from today onwards the purchaser/vendee shall be entitled to mutate his or her name ',
#  '11.  That the Vendee is hereby entitled to get the said property transferred in his name in all ',
#  '12.  The present market value of the property is Rs. ……… …….. (Rupees………………….) only. ',
#  'VENDOR        VENDEE \n ',
#  '1. \n \n2. ',
#  '2. GIFT: ',
#  'DEED OF GIFT OF IMMOVABLE PROPERTY \n ',
#  'SCHEDULE ',
#  '1. \n2. ',
#  'SIMPLE MORTGAGE DEED \n ',
#  'NOW THIS DEED WITNESSETH THAT',
#  'AND THIS DEED FURTHER WITNESSETH THAT ',
#  'AND IT IS HEREBY AGREED AND DECLARED ',
#  'AND IT IS FURTHER AGREED AND DECLARED ',
#  'AND IT IS FURTHER AGREED  ',
#  'AND IT IS FURTHER AGREED BY THE MORTGAGOR ',
#  '1. \n \n2.',
#  'DEED OF MORTGAGE BY CONDITIONAL SALE \n ',
#  'NOW THIS DEED WITNESSETH THAT ',
#  '1. \n Pursuant to the said agreement and in consideration  of the said sum of Rs ....... paid by the ',
#  '2.  And it is hereby agreed and declared that if the Ve ndor shall at any time hereafter repay to ',
#  '3.  Provided however and it is agreed that, if the Vend or or his heirs, executors, administrators ',
#  '4.  And the Vendor doth hereby covenants with the Purch aser that – ',
#  '1. \n2. ',
#  '4. LEASE: ',
#  'GENERAL LEASE DEED \n ',
#  'WHEREAS ',
#  '1. \n The Lessor is in complete possession of the buildin g bearing Municipal No------ Situated at -- ',
#  '2.  On the request of the Lessee, the Lessor has agreed  to grant lease in respect of the ',
#  '1. In pursuance of the said agreement and in consid eration of the rent hereby reserved and of ',
#  '2. The Lessee hereby covenants with the Lessor as f ollows: ',
#  '3.  The Lessor hereby agrees with the Lessee as follows : ',
#  '4. It is hereby agreed that if the rent or any part  thereof payable in respect of the demised ',
#  '5. If within a period of one month after the issue of such notice, the Lessee does not pay the ',
#  'WITNESSES ',
#  '1. \n \n2.',
#  'COMMERCIAL LEASE DEED \n \n ',
#  '1. \n The Landlord agrees to let out and the tenant agree s to take on rent the ground floor portion ',
#  '2.  The tenant has paid Rupees ______ as advance amount  for the above building and the ',
#  '3.  At the termination of the period of tenancy the ten ant agrees to surrender to the Landlord ',
#  '4.  This rental agreement can be terminated at any time  by three months notice on either side ',
#  '5.  If for by any reason the tenant occupies the buildi ng for a period that includes part of a ',
#  '6.  The landlord shall pay all existing and future taxe s, rates and assessments in respect of the ',
#  '7.  The tenant shall pay the electricity and water supp ly charges for the period of time he ',
#  '8.  The tenant agrees to leave at the end of tenancy th e premises in good condition as theyare ',
#  '9.  The tenant also agrees not to let out the building or a portion of it to anybody else. ',
#  '10.  The tenant shall not commit any act of waste in the  premises. ',
#  '11.  The tenant also agrees to pay any maintenance on th e building as mutually agreed upon by ',
#  '12.  It is hereby agreed that the tenant paying the rent  hereby reserved, and performing and ',
#  '13.  The agreement does not cover the property adjoining  the premises and the landlord shall be ',
#  '14.  The landlord shall retain the original of this agre ement and the tenant shall retain its ',
#  '1. \n \n2. ',
#  'LEASE OF FURNISHED HOUSE FOR RESIDENTIAL PURPOSE \n ',
#  '1. \n In pursuance of the said agreement and in considera tion of the rent hereby reserved and of ',
#  '2.  The lessee hereby for himself, his heirs, executors , covenants administrators and assigns, ',
#  '3. The Lessor hereby agrees to the following covena nts: ',
#  '4. It is hereby agreed between the parties as follo ws: ',
#  '5. Until the Landlord and the tenant shall otherwis e advise each other in writing, their addresses ',
#  '6. This Lease Deed shall be executed in duplicate. The original shall be retained by the ',
#  '7. The stamp duty and all other expenses in respect  of this Lease Deed and duplicate thereof ',
#  '1. \n2.',
#  'DEED OF SURRENDER OF LEASE \n ',
#  'BETWEEN ',
#  '1. \n2.',
#  '1. \n  \n2. ',
#  '5. \n LEAVE AND LICENCE: ',
#  'LEAVE AND LICENCE AGREEMENT \n ',
#  'BETWEEN ',
#  'AND ',
#  'NOW THIS AGREEMENT TO LEAVE AND LICENCE WITNESSETH AND IT IS HEREBY ',
#  '1.  The Licensors shall grant unto the Licensee and the  Licensee hereby accepts from the ',
#  '2.  The duration of the licence hereby granted shall be  for a period of two years only ',
#  '3.  In consideration of the Licensors permitting the Li censee to use and occupy the licensed ',
#  '4.  In addition to the aforesaid payment of the said su m of Rs.__________ (Rupees ',
#  '5.  The Licensee hereby covenants with the Licensors as  under: ',
#  '6. The Licensors hereby covenants with the Licensee  as follows:- ',
#  '7. If at any time during the said term the said pre mises are damaged or destroyed by fire, storm, ',
#  '8. On expiry or sooner determination of this Licenc e, the Licensee shall remove its employees ',
#  '9. The Licensee shall permit the Licensors and thei r agents at all times to enter upon the said ',
#  '10. It is the express intention of the parties here to that the Agreement shall be a mere Licence, ',
#  '11. It is hereby agreed by and between the parties hereto that in case if any of the terms and ',
#  '12. In the event of the Licensee failing to hand ov er to the Licensors possession of the licensed ',
#  '13. The Licensors hereby represent and declare that ; ',
#  '14. Any notice required to be given hereunder shall  be sufficiently served on the Licensors, if ',
#  '6.  PARTNERSHIP DEED:  ',
#  'PARTNERSHIP DEED \n ',
#  'AND ',
#  '1. \n The Partnership shall come into effect from _______ ___________and shall be for an ',
#  '2.  That the name and style of the Partnership firm her eby formed shall be ',
#  '3.  That the business of the Partnership Firm hereby fo rmed shall be that of manufacturing and ',
#  '4.  That the amount standing to the credit of the perso nal accounts of the Parties of First and ',
#  '5.  That further finance required for the purpose of bu siness of the firm shall be contributed by ',
#  '6.  That the regular accounts books shall be kept in du e course of business in which shall be ',
#  '7.  That on closing the account books in the aforesaid manner, a regular profit & Loss Account ',
#  '8.  That the Profits & Losses shall be divided between and borne by parties hereto in the ',
#  '9. \n That the partners will be paid a Salary of Rs._____ ______/- per month for the services ',
#  '10.  That all the assets and liabilities of the firm as on ___________ tangible or otherwise, would ',
#  '11.  That all rights of the firm as on _____________name ly licences, Trademarks, VAT ',
#  '12.  That each partner shall: - ',
#  '13. That neither Partner shall without the consent of the others: - ',
#  '14. That the account in the name of the firm ______ ______ shall be opened with the Banks or ',
#  '15. That any partner may retire from the Partnershi p firm, hereby formed by giving ____ months ',
#  '16. That the parties hereto may, however, with thei r mutual consent pay remuneration to any of ',
#  '17. That in the event of death or retirement of any  of the parties hereto the partnership firm ',
#  '20. That without prejudice to the above terms and c onditions the parties hereto in all other ',
#  '21. That all the disputes or differences arising ou t of it and connected with the Partnership shall ',
#  '1. \n2. ',
#  '3.\n28 ',
#  '7.  TRUST DEED: ',
#  'DEED OF TRUST \n ',
#  'BETWEEN \n ',
#  'AND ',
#  '1. _________________ S/O. ________________, residin g at ____________ & ',
#  '2. __________________S/O. ________________, residin g at ____________ & ',
#  '3. SMT. W/O SHRI. , of ____________ ',
#  '1. Settlement: ',
#  '2. Name: ',
#  '3. Place: ',
#  '4. Objects: ',
#  '5. Beneficiaries: ',
#  '6. Properties: ',
#  '7. Funds: ',
#  '8. Investments: ',
#  '9. Number of Trustees and their Term: ',
#  '10. Administration of Trust and Power of Board ',
#  '11. Roles and Responsibilities: ',
#  '12. Meeting of the Board of Trustees:  ',
#  '13. Bank Account: ',
#  '14. Accounts And Audit: ',
#  '15. Irrevocable: ',
#  '16. Amendments: ',
#  '17. Amalgamation: ',
#  '18. Settlor and their Relatives: ',
#  '19. Applicability Of Trust Act: ',
#  '20. Dissolution: ',
#  'SCHEDULE ',
#  '1. Cash contribution to the Corpus Fund of the Trus t of Rupees --------------- (Rupees -------------- ',
#  '2. Properties of -------------------------------------------------------------------------- ',
#  '3. Assets of -----------------------------------------------------------------------------',
#  'SETTLOR \n ',
#  '1.         2. TRUSTEE ____________ ',
#  '2.         3. TRUSTEE ____________ ',
#  '8.  BONDS ',
#  'SIMPLE MONEY BOND ',
#  '1. \n2. ',
#  'MONEY BOND WITH SURETY ',
#  'AB \n \nCD \n \nINDEMNITY BOND \n ',
#  '1. That the said transfer which is being effected i n the name of ………….. is a friendly transfer ',
#  'INDEMNIFIERS \n ',
#  '1. \n2. ',
#  '9. \n PARTNERSHIP AGREEMENTS ',
#  'DEED OF DISSOLUTION \n ',
#  '1. ______________ S/o. _________________________ ag ed about _____ years R/o ',
#  'AND ',
#  '1. THAT the partnership firm stands dissolved as on  _____ day of ____________ 20___ and ',
#  '2. THAT the assets and liabilities remaining as on _____ day of ____________ 20__ have been ',
#  '3. THAT the firm stands dissolved as on _________ w .e.f. _____ day of ____________ ',
#  '4. THAT with a view to give full and complete effec t to this dissolution the accounts of the late ',
#  '5. THAT the continuing Party shall clear and pay as  referred to in clause 3 above to the retiring ',
#  '6. THAT the hereto retiring parties shall not herei nafter collect any assets claims and/or dues of ',
#  '7. THAT all the books of accounts, bills, vouchers and other documents belonging to the said ',
#  '8. THAT the hereto retiring party undertakes to do and sign all such deeds, documents and ',
#  '3. ._____________ ',
#  '4. .________________ ',
#  'BETWEEN ',
#  'AND ',
#  '1. The parties hereto shall hold the said property being flat no.___________ in ',
#  '2. The expenses and outgoings in respect of the afo resaid property and the rent, profits, ',
#  '3. It is hereby agreed that if the said property or  part thereof is sold or otherwise ',
#  '4. If either of the parties hereto wishes to dispos e of his interest in the said property he ',
#  '5. All the documents of title in respect of the sai d property shall be kept in the custody of ',
#  '1. \n That in consideration of the right title and intere st made in accordance with the aforesaid ',
#  '2.  That the original deed of partition shall be retain ed by first party, at true copy thereof signed ',
#  '3.  That the parties have agreed that all taxes and pub lic charges in respect of the allotted ',
#  '4.  That each party will execute such deed or do all ot her acts necessary which may be ',
#  '5.  That the valuation of the entire property under thi s partition-deed is fixed at Rs.__________. ',
#  '1. First party ',
#  '2. Second party ',
#  '3. Third party ',
#  '10. \n RELINQUISHMENT / RELEASE:  ',
#  'RELINQUISHMENT DEED \n ',
#  'IN FAVOUR OF ',
#  'RELEASEE \n ',
#  '1. \n \n2.',
#  '11. EXCHANGE:  ',
#  'EXCHANGE DEED ',
#  'FIRST SCHEDULE ',
#  'SECOND SCHEDULE ',
#  'FIRST PARTY       SECOND PARTY \n ',
#  '1. \n \n2. ',
#  'EXCHANGE DEED ',
#  '1. In pursuance of the said agreement, the party of  the One Part hereby grants, transfers and ',
#  '2. In further pursuance of the said Agreement, the party of the Other Part hereby grants, ',
#  '3. Each of the parties hereto covenants with the ot her – ',
#  '4. That the part of the One Part has paid on or bef ore the execution of this Deed a sum of ',
#  '5. The original Deed of Exchange shall be retained by the Party of the One Part and the ',
#  'FIRST SCHEDULE ',
#  'SECOND SCHEDULE ',
#  '12. CANCELLATION:  ',
#  'CANCELLATION DEED ',
#  'SCHEDULE \n \n ',
#  '13. POWER OF ATTORNEY ',
#  'GENERAL POWER OF ATTORNEY \n ',
#  '1. Commercial:  ',
#  '1.1 To transact business:- To commence, transact, m anage, carry on, close down any of ',
#  '1.2 To buy and sell:- To buy, receive, store and ho ld and to sell, pledge, hypothecate, ',
#  '1.3 To open branches:- To open, establish, conduct,  shift and/or close any branch of any ',
#  '1.4 To contract:- To enter into, sign, execute, var y, alter, terminate, suspend, and ',
#  '1.5 Partnership business:- To act as a partner in t he firm or firms in which I am a partner ',
#  '2. Property:  ',
#  '3. Companies: ',
#  '4. Investments:  ',
#  '5. Banking ',
#  '6. Money: ',
#  '6.3 Miscellaneous: ',
#  '7. Representations: ',
#  '8. Trusts:  ',
#  '9. Execution and registration of documents:  ',
#  '11. Receipts and discharges:  ',
#  '12. Agents:  ',
#  '13. Miscellaneous:  ',
#  '14. To substitute and appoint in his place (on such  terms and conditions as my said attorney ',
#  '15. AND in case of death of the said attorney or in ability or unwillingness to act through illness ',
#  '16. And generally my said attorney shall have the p ower to do all such acts, deeds and things ',
#  '1. \n2. ',
#  'SPECIAL POWER OF ATTORNEY  ',
#  'POWER OF ATTORNEY TO EXECUTE SALE DEED \n ',
#  '1. \n To negotiate and sell my property situated at ----- ------------ to any purchaser at such price and at ',
#  '2.  To receive from the purchaser the consideration mon ey for the said property and to give receipt ',
#  '3.  To deliver physical possession in the manner that i s possible in the circumstances of the said ',
#  '4.  To apply to the Municipal Corporation of -------------- for mutation of the said property in favour of  ',
#  '1. \n2. ',
#  'DEED OF REVOCATION OF POWER OF ATTORNEY \n ',
#  '1. I do hereby confirm that I have cancelled and re voked the said Power of Attorney granted to ',
#  '1.  \n2. ',
#  '14. WILLS: ',
#  'WILL \n ',
#  '1. \n I hereby revoke all Wills and Testamentary disposit ions which I may have herein ',
#  '2. \n I bequeath on my death, to ______________________, my title, interests, and all ',
#  '3.  I have ancestral lands in my native village, ------ ------. My son……… and daughter ',
#  '4.  I bequeath on my death the following ornaments and jewellery belonging to me ',
#  '5.  I bequeath on my death, cash balance lying with me at the time of my death ',
#  '6.  I bequeath on my death, bank balance lying in my na me at Savings / Current Bank ',
#  '7.  I bequeath the amounts receivable by me at the time  of my death from various parties ',
#  '8.  I bequeath the amounts and other valuables owned by  me and lying in locker ',
#  '9.  I direct that a sum of rupees ________________ Only  (Rs. _____/-) be set apart from ',
#  '10.  I direct that before distributing my assets in acco rdance with this will, all my debts, ',
#  '11.  I bequeath all other residuary property, assets and  other rights whether or not ',
#  '1. I have witnessed and read the aforesaid Will. ',
#  '2. I have witnessed and read the aforesaid Will. ',
#  '15. ADOPTION DEED: ',
#  'GENERAL ADOPTION DEED \n ',
#  'BETWEEN \n ',
#  'AND \n ',
#  'WHEREAS \n ',
#  '1.  The adoptive father has no issue, male or female, a nd having regard to his ',
#  '2.  The adoptive father and his wife want to adopt a ch ild as their son/daughter. ',
#  '3.  The natural father has three children, all sons. ',
#  '4.  The adoptive father, with the consent of his wife, has approached the natural father for ',
#  '5.  The natural father has, with the consent of his wif e, consented to his said son being ',
#  '6.  The ceremony of giving and taking in adoption has b een duly performed along with ',
#  '7.  The parties considered it expedient and necessary t hat a proper deed of adoption be ',
#  '1. Declaration of Adoption: ',
#  '2. Legal rights and liabilities of adopted son:  ',
#  '3. Maintenance, etc. of adopted son:  ',
#  'THE ADOPTIVE FATHER      THE NATURAL FATHER ',
#  '1. \n \n \n2.',
#  'ADOPTION OF AN ORPHAN FROM AN ORPHANAGE \n \n ',
#  'WHEREAS ',
#  '1. \n I have no issue of my own and have no expectation o f having any issue due to the reason of ',
#  '2.  I have long been anxious to adopt a suitable boy/gi rl as our son/ daughter. ',
#  '3.  I have, after taking consent of my wife, adopted __ _________ aged _________, residing ',
#  '4.  The ceremony of giving and taking in adoption has b een duly performed on ________ along ',
#  '1.       Sh.______________ ',
#  '2. \n \n \n16. SETTLEMENT: ',
#  'FAMILY SETTLEMENT BETWEEN THE HEIRS OF A DECEASED \n ',
#  '1. In pursuance of the said agreement and in consid eration of the premises, the parties ',
#  '1. \n2. ',
#  '3. \n4. ',
#  '5. \n \n2. The parties hereby declare that they have taken independent advice from their respective ',
#  'SCHEDULE ',
#  '1. \n \n2. ']

# %%
clauses = {}

for i, heading in enumerate(headings):  # 'headings' = your extracted list
    start = cleaned_text.find(heading)
    
    # determine end of section
    if i < len(headings) - 1:
        end = cleaned_text.find(headings[i+1])
    else:
        end = len(cleaned_text)

    section_text = cleaned_text[start:end].strip()
    clauses[heading] = section_text

# Show total clauses
len(clauses)
# Out:
# 172

# %%
sample_heading = list(clauses.keys())[0]
print("Heading:", sample_heading)
print("\n---\n")
print(clauses[sample_heading][:1500])
# Out:
# Heading: NOC
#
# ---
#
# NOC from local authorities if the document for regi stration conveys land converted as house site without the approval layout. (i) Patta transfer application duly filled and signed. Compulsory registrable documents: Sl.No Situation / documents 1. Instruments of gift of immovable property 2. Other non-testamentary instruments which purport or operate to create, declare, assign, limit or extinguish, whether in present or in future, any right, title or interest, whether vested or contingent, of the value of one h undred rupees, and upwards, to or in immovable property 3. Non-testamentary instruments which acknowledge t he receipt or payment of any consideration on account of the creation, declarati on, assignment, limitation or extinction of any such right, title or interest 4. Leases of immovable property from year to year, or for any term exceeding one year, or reserving a yearly rent 5. Non-testamentary instruments transferring or ass igning any decree or order of a court or any award when such decree or order or awa rd purports or operates to create, declare, assign, limit or extinguish, wheth er in present or in future, any right, title or interest, whether vested or conting ent, of the value of one hundred rupees and upwards, to or in immovable property 6. Authority to adopt a son and not conferred by a Will. 2 1.

# %% [markdown]
# ## Creating AGENTS

# %% [markdown]
# As the OpenAI API free version is not available, I am using the langchain-grok and accessing the llama model

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=os.getenv("GROQ_API_KEY")
)

# %%
AGENT_PROMPTS = {
    "compliance": """
You are a **Regulatory Compliance Analysis Agent** specializing in auditing legal and operational clauses in contracts.

### Your Objectives
- Identify compliance risks, violations, missing mandatory clauses, or inconsistencies.
- Check if the clause follows required government, financial, environmental, and operational regulations.
- Highlight missing approvals/NOCs/permits/licenses required for execution.
- Detect ambiguous or unenforceable compliance language.

### Your Analysis Procedure
1. Interpret the clause in clear terms.
2. Identify every compliance-related requirement.
3. Evaluate if the clause satisfies legal and regulatory obligations.
4. Flag any risks, missing documents, gaps, or violations.
5. Provide clear compliance recommendations.

### Output Format
Return the answer in this structure:

**1. Interpretation**  
A simple explanation of what the clause means.

**2. Compliance Risks**  
- Itemized bullet list of potential risks  
- Cite the specific problematic wording

**3. Missing Requirements**  
List permits, NOCs, statutory filings, approvals, supporting documents.

**4. Recommendations**  
Clear actionable steps to make the clause compliant.
""",
"finance": """
You are a **Financial Terms Analysis Agent** specializing in monetary clauses in legal contracts.

### Your Objectives
- Extract and interpret financial obligations, penalties, fees, deposits, rent, consideration amounts, etc.
- Detect vague or risky financial language.
- Identify payment timelines, interest rates, liabilities, default penalties.
- Flag inconsistencies that could create financial disputes.

### Your Analysis Procedure
1. Break down every financial term and obligation.
2. Identify unclear, missing, or high-risk monetary conditions.
3. Detect obligations tied to taxes, duties, maintenance, reimbursements.
4. Highlight risk exposure for both parties.

### Output Format

**1. Financial Breakdown**  
List all monetary elements in the clause.

**2. Financial Risks**  
- Vague or missing payment terms  
- Potential liabilities  
- Ambiguous obligations

**3. Inconsistencies**  
Compare obligations mentioned vs. implied vs. missing.

**4. Recommendations**  
Financial clarity and risk-reduction steps.
""", 
"legal": """
You are a **Legal Interpretation Agent** trained to read, analyze, and break down contractual clauses for accuracy, enforceability, and legal soundness.

### Your Objectives
- Interpret legal meaning precisely but explain simply.
- Identify rights, duties, liabilities of each party.
- Detect loopholes, ambiguous phrasing, unenforceable terms.
- Identify legal risks or missing elements required for a valid clause.

### Your Analysis Procedure
1. Precisely interpret the clause in plain English.
2. Identify legal obligations of all parties.
3. Detect ambiguous, contradictory, or unenforceable language.
4. Spot missing legal components essential for validity.
5. Highlight legal risks.

### Output Format
Respond in this structured format:

**1. Legal Interpretation**  
Explain the meaning clearly.

**2. Obligations Identified**  
- Party A responsibilities  
- Party B responsibilities  
- Conditions, timelines, dependencies

**3. Legal Issues / Risks**  
List loopholes, unclear terms, unenforceability problems.

**4. Missing Legal Elements**  
Documents, approvals, signatures, timelines, etc.

**5. Recommendations**  
Add clarity, precision, enforceability.
""",
"operations": """
You are an **Operations Workflow Analysis Agent** specializing in identifying deliverables, timelines, processes, and practical execution steps in a contract.

### Your Objectives
- Extract all operational duties and workflows.
- Identify deliverables, timelines, responsibilities, and dependencies.
- Detect vague instructions or missing execution details.
- Highlight operational risks or inconsistencies.

### Your Analysis Procedure
1. Break the clause into operational actions.
2. Identify who is responsible for what.
3. Detect missing timelines, unclear deliverables, or contradictions.
4. Highlight operational bottlenecks or risk-prone areas.

### Output Format

**1. Operational Breakdown**  
List the tasks, responsibilities, and processes.

**2. Missing Details**  
Timelines, deliverables, performance measures, reporting steps.

**3. Risks & Ambiguities**  
Operational failure points.

**4. Recommendations**  
Clear actions to improve operational clarity.
"""
}

# %%
def analyze_clause_with_agent(agent_type: str, clause_text: str):
    if agent_type not in AGENT_PROMPTS:
        raise ValueError(f"Unknown agent: {agent_type}")

    prompt = (
        AGENT_PROMPTS[agent_type]
        + "\n\n---\nCLAUSE TO ANALYZE:\n"
        + clause_text
        + "\n---\nProvide your structured analysis below."
    )

    response = llm.invoke(prompt)
    return response.content

# %%
analysis_test = analyze_clause_with_agent("legal", clauses[sample_heading])
print(analysis_test)
# Out:
# **1. Legal Interpretation**
# The given clause pertains to the registration of immovable property and the necessary documents required for such registration. It mentions the need for a No Objection Certificate (NOC) from local authorities if the land is being converted into a house site without an approved layout. Additionally, it lists various types of compulsory registrable documents, including gifts, leases, and other non-testamentary instruments that affect the rights, title, or interest in immovable property. These documents must be duly filled, signed, and registered to be considered valid.
#
# **2. Obligations Identified**
# - **Party A (Seller/Transferor) Responsibilities**:
#   - To obtain a NOC from local authorities if the land is being converted into a house site without an approved layout.
#   - To provide duly filled and signed Patta transfer application.
#   - To ensure all necessary documents for registration are provided and are in order.
# - **Party B (Buyer/Transferee) Responsibilities**:
#   - To verify the authenticity and completeness of the documents provided by Party A.
#   - To ensure that all registrations are properly done and recorded.
# - **Conditions, Timelines, Dependencies**:
#   - The registration process is contingent upon the receipt of a NOC from local authorities, if applicable.
#   - The process also depends on the timely and correct submission of all required documents.
#   - There might be specific timelines for the submission and registration of these documents, which are not detailed in the given clause.
#
# **3. Legal Issues / Risks**
# - **Ambiguity in "approval layout"**: The term "approval layout" is not clearly defined, which could lead to confusion about what specific approvals are required.
# - **Unclear Terms in "Non-testamentary instruments"**: The clause lists various non-testamentary instruments without providing clear definitions or examples, which could lead to confusion.
# - **Potential for Fraud**: Without clear guidelines on the verification of documents, there is a risk of fraudulent documents being submitted.
# - **Unspecified Penalties for Non-compliance**: The clause does not specify the consequences of failing to register the necessary documents or obtain the required NOC, which could lead to legal disputes.
#
# **4. Missing Legal Elements**
# - **Specific Definitions**: Definitions for key terms such as "approval layout," "non-testamentary instruments," and "compulsory registrable documents" are missing.
# - **Timelines for Registration**: The clause does not specify the timeframe within which the registration must be completed.
# - **Penalties for Non-compliance**: There is no mention of the penalties or consequences for failing to comply with the registration requirements.
# - **Verification Process**: The process for verifying the authenticity and completeness of the documents is not detailed.
#
# **5. Recommendations**
# - **Add Clear Definitions**: Include clear and concise definitions for all technical and legal terms used in the clause.
# - **Specify Timelines**: Clearly outline the timelines for the submission, verification, and registration of documents.
# - **Detail Verification Process**: Provide a detailed process for the verification of documents to prevent fraud and ensure compliance.
# - **Outline Penalties for Non-compliance**: Specify the penalties or consequences for failing to comply with the registration requirements to ensure adherence to the law.
# - **Seek Legal Counsel**: It is recommended that both parties seek legal counsel to ensure that all legal requirements are met and that their rights are protected.

# %% [markdown]
# ## Week-2 Tasks

# %% [markdown]
# ### 1. Developing a Planning module to handle multi-agent collaboration

# %%
import json
import re

def extract_json(text):
    """
    Extract the first valid JSON object from the LLM response.
    """
    try:
        # Try direct load
        return json.loads(text)
    except:
        pass

    # If the model added extra text, try regex to pull the JSON part
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if match:
        try:
            return json.loads(match.group(0))
        except:
            pass

    raise ValueError("No valid JSON found in model output:\n" + text)

# %%
from langchain_groq import ChatGroq

planner_llm = ChatGroq(
    model="llama-3.1-8b-instant",   # fast + perfect for planning
    api_key=os.getenv("GROQ_API_KEY")
)

# %%
PLANNING_PROMPT = """
You are a Planning Controller Agent.

Your tasks:
- Read the contract clause.
- Decide which specialized agents are needed:
    - compliance
    - finance
    - legal
    - operations
- Give the decision in a structured JSON plan.

The JSON must be in this format:

{
  "agents": ["legal", "compliance"],
  "reason": "Short explanation of why these agents are needed.",
  "steps": [
      "Run legal agent for interpretation",
      "Run compliance agent for regulatory validation"
  ]
}

Now read the clause and generate a plan.

CLAUSE:
{{CLAUSE}}
"""

# %%
import json

def planning_module(clause_text):
    prompt = f"""
You are a Contract Planning Module.

Read the clause below and decide which AI agents must be activated.

Return ONLY a JSON in this exact structure:

{{
  "agents": ["legal", "compliance"],
  "reason": "why these agents are needed",
  "steps": [
      "analyze with legal",
      "analyze with compliance"
  ]
}}

Clause:
\"\"\"{clause_text}\"\"\"
"""

    response = llm.invoke(prompt).content
    plan = extract_json(response)
    return plan

# %%
sample_clause = clauses[sample_heading]  # or choose from your parsed dict

plan = planning_module(sample_clause)
plan
# Out:
# {'agents': ['legal', 'compliance'],
#  'reason': 'The clause deals with legal documents, registration, and property transfer, which requires analysis by legal and compliance agents to ensure adherence to regulations and laws.',
#  'steps': ['analyze with legal', 'analyze with compliance']}

# %%
def run_agents_on_clause(clause_text, plan):
    results = {}

    for agent in plan["agents"]:
        print(f"\n🔹 Running agent: {agent} ...")

        analysis = analyze_clause_with_agent(agent, clause_text)
        results[agent] = analysis

    return results

# %%
def analyze_clause_pipeline(clause_text):
    print("📌 Step 1: Planning...")
    plan = planning_module(clause_text)
    print("➡ Plan:", plan)

    print("\n📌 Step 2: Running agents...")
    agent_outputs = run_agents_on_clause(clause_text, plan)

    print("\n📌 Step 3: Final Combined Output Ready.")
    return {
        "plan": plan,
        "agents": agent_outputs
    }

# %%
result = analyze_clause_pipeline(sample_clause)
result
# Out:
# 📌 Step 1: Planning...
# ➡ Plan: {'agents': ['legal', 'compliance'], 'reason': 'The clause deals with legal documents, registration, and property rights, requiring analysis by legal and compliance agents to ensure adherence to regulations and laws.', 'steps': ['analyze with legal', 'analyze with compliance']}
#
# 📌 Step 2: Running agents...
#
# 🔹 Running agent: legal ...
#
# 🔹 Running agent: compliance ...
#
# 📌 Step 3: Final Combined Output Ready.
# {'plan': {'agents': ['legal', 'compliance'],
#   'reason': 'The clause deals with legal documents, registration, and property rights, requiring analysis by legal and compliance agents to ensure adherence to regulations and laws.',
#   'steps': ['analyze with legal', 'analyze with compliance']},
#  'agents': {'legal': '**1. Legal Interpretation**\nThe given clause pertains to the requirement of a No Objection Certificate (NOC) from local authorities for the registration of land converted into a house site without an approved layout. It also lists various types of documents that are compulsorily registrable, including gifts, leases, and assignments of immovable property, among others. These documents must be duly filled, signed, and meet specific criteria such as value thresholds to be considered registrable.\n\n**2. Obligations Identified**\n- **Party A Responsibilities**: Obtain NOC from local authorities for land conversion, prepare and sign necessary documents for registration (e.g., patta transfer application).\n- **Party B Responsibilities**: Provide approval for layout, process registration applications, and maintain records of registrable documents.\n- **Conditions, Timelines, Dependencies**: The requirement for an NOC is contingent upon the land being converted into a house site without an approved layout. The timeline for obtaining the NOC and registering the documents is not specified, but it is implied that these steps must be taken prior to or concurrently with the registration process.\n\n**3. Legal Issues / Risks**\n- **Ambiguity in Value Threshold**: The clause mentions a value of "one hundred rupees and upwards" for certain transactions to be registrable, which may be too low considering current market values and could lead to unnecessary registrations or disputes over what constitutes a significant enough transaction.\n- **Unclear Terms**: The phrase "whether in present or in future" could introduce ambiguity regarding the timing of the creation, declaration, assignment, limitation, or extinction of rights, titles, or interests in immovable property.\n- **Unenforceability Problems**: The enforceability of certain clauses, especially those related to the transfer of decrees or orders of a court, might be challenging without specific legal frameworks or jurisdictions being referenced.\n- **Lack of Specification on Authority**: The clause does not specify which local authorities are responsible for issuing the NOC, which could lead to confusion.\n\n**4. Missing Legal Elements**\n- **Jurisdiction**: The clause does not specify under which jurisdiction these regulations apply, which is crucial for understanding the legal framework.\n- **Penalties for Non-Compliance**: There is no mention of penalties or consequences for failing to obtain an NOC or register the specified documents, which could undermine the enforceability of these requirements.\n- **Timeline for Registration**: A specific timeline for the registration of documents after they are duly filled and signed is not provided, which could lead to delays or disputes.\n- **Definition of "Immovable Property"**: While the clause deals extensively with immovable property, it does not provide a definition, which could be necessary for clarity, especially in cases where the nature of the property is disputed.\n\n**5. Recommendations**\n- **Add Clarity on Value Thresholds**: Update the value threshold to reflect current market values or tie it to an index to ensure it remains relevant.\n- **Specify Authority and Jurisdiction**: Clearly state which local authorities are responsible for issuing NOCs and under which legal jurisdiction these regulations apply.\n- **Define Key Terms**: Provide definitions for key terms such as "immovable property" to avoid ambiguity.\n- **Include Penalties for Non-Compliance**: Specify the penalties or consequences for failing to comply with the requirements for obtaining an NOC or registering documents to enhance enforceability.\n- **Establish Timelines**: Set clear timelines for the registration process and the issuance of NOCs to ensure efficiency and transparency.',
#   'compliance': '**1. Interpretation**\nThe clause requires a No Objection Certificate (NOC) from local authorities when registering a document that involves the conversion of land into a house site without an approved layout. It also lists various types of compulsory registrable documents related to immovable property, including gifts, leases, and non-testamentary instruments that create, assign, or extinguish rights, titles, or interests in such property.\n\n**2. Compliance Risks**\n- The clause does not specify the exact conditions under which the NOC from local authorities is required, which could lead to ambiguity and potential non-compliance.\n- The phrase "without the approval layout" is unclear and may cause confusion, citing the problematic wording: "land converted as house site without the approval layout."\n- The list of compulsory registrable documents seems comprehensive but may not be exhaustive, potentially leading to overlooked requirements.\n- The clause does not address the consequences of non-registration of these documents, citing the lack of clear enforcement mechanisms.\n- The requirement for a "Patta transfer application duly filled and signed" may not be applicable in all jurisdictions or situations, potentially causing inconsistencies.\n\n**3. Missing Requirements**\n- Specific approvals from local authorities for land conversion.\n- Detailed documentation of the land conversion process.\n- Proof of payment of applicable fees for registration and NOC.\n- Certified copies of identity and address proofs of the parties involved.\n- Environmental clearance certificates, if applicable.\n- Approval from relevant government departments for the conversion of land use.\n\n**4. Recommendations**\n1. **Clarify Conditions for NOC**: Specify the exact conditions under which an NOC from local authorities is required, including the type of land conversion and the necessary approvals.\n2. **Define Approved Layout**: Clearly define what constitutes an "approved layout" to avoid ambiguity and ensure compliance.\n3. **Enumerate Consequences of Non-Registration**: Outline the consequences of failing to register the listed documents to ensure enforcement and compliance.\n4. **Jurisdictional Considerations**: Ensure that the clause accounts for variations in requirements across different jurisdictions.\n5. **Include Environmental and Social Impact Assessments**: If applicable, require environmental clearance certificates and social impact assessments for land conversions that could have significant environmental or social effects.\n6. **Standardize Documentation**: Specify the exact documentation required for each type of registrable document to ensure consistency and completeness.\n7. **Consult Legal and Regulatory Experts**: Review the clause with legal and regulatory experts to ensure it meets all current and proposed regulatory requirements.'}}
